# %% [markdown]
# # Import modules

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import qiskit
import pylatexenc
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import gym
from functools import reduce
from collections import deque, defaultdict

# %%
import qiskit
import numpy as np
import matplotlib.pyplot as plt
import math, random, time, itertools
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer
from qiskit.quantum_info.operators import Operator
from qiskit.circuit import Parameter, ParameterVector
from tqdm.notebook import tqdm
from qiskit.opflow import Z, X, I, StateFn, CircuitStateFn, SummedOp, CircuitOp, AerPauliExpectation, Zero, One, ListOp, PauliSumOp
from qiskit.opflow.gradients import Gradient, NaturalGradient, QFI, Hessian
from qiskit_machine_learning.connectors import TorchConnector
from qiskit_machine_learning.neural_networks import OpflowQNN
from qiskit.utils import QuantumInstance, algorithm_globals

# %%
from Curling_omega import Curling
from ansatz import build_circuit

# %% [markdown]
# # Build CIrucit

# %% [markdown]
# ### Ansatz list
# - 'base'
# - 'hw_eff'
# - 'universal'
# - 'universal_encoding'

# %%
def draw_example():
    quantum_circuit, param_rot, param_enc = build_circuit(n_qubits=2, n_layers=1, opt='omega')
    return quantum_circuit
draw_example().draw('mpl')

# %%
# circuit, rot_params, enc_params = build_circuit(n_qubits=2, n_layers=1)

# %%
class PQC_with_DataReuploading(nn.Module):
    def __init__(self, n_qubits, n_layers, output_dim, observables=None, ansatz='base', activation='linear'):
        super().__init__()
        
        self.n_qubits = n_qubits
        self.n_layers = n_layers
        self.output_dim = output_dim
        self.activation = activation
        self.ansatz = ansatz
        
        if observables == None:
            self.observables = Z^n_qubits
        else:
            self.observables = observables
        
        # Build circuits / Parameter Vectors
        self.circuit, self.rot_params, self.enc_params = build_circuit(self.n_qubits, self.n_layers, ansatz)
        self.len_rot_params = len(self.rot_params)
        self.len_enc_params = len(self.enc_params)
        
        self.psi = CircuitStateFn(primitive=self.circuit, coeff=1.)
        self.Op = ~StateFn(self.observables) @ self.psi
#         print(self.Op)
        # set method to calculcate expected values
        expval = AerPauliExpectation()
        # define gradient method
        gradient = Gradient(grad_method='param_shift')
        # define quantum instances (statevector and sample based)
        qi_sv = QuantumInstance(Aer.get_backend("aer_simulator_statevector"))
        # we set shots to 10 as this will determine the number of samples later on.
        qi_qasm = QuantumInstance(Aer.get_backend("aer_simulator"), shots=1000)
        
        self.qnn = OpflowQNN(operator=self.Op, input_params=self.enc_params, weight_params=self.rot_params, 
                             exp_val=expval, gradient=gradient, quantum_instance=qi_sv, input_gradients=True)
        
        self.total_params = []
        for p in self.rot_params:
            self.total_params.append(p)
        for p in self.enc_params:
            self.total_params.append(p)
        
        # Initial Parameters for circuit
        self.rot_param_vals = nn.Parameter(2*np.pi * torch.rand(len(self.rot_params)))
#         self.rot_param_vals = nn.Parameter(torch.tensor([-np.pi/2+0.1*np.random.rand(), -np.pi+0.1*np.random.rand(),
#                                                          -np.pi/2+0.1*np.random.rand(), -np.pi+0.1*np.random.rand()]))
#         self.enc_param_vals = nn.Parameter(torch.ones(len(self.enc_params)))
        self.enc_param_vals  = nn.Parameter(torch.rand(len(self.enc_params)))
#         self.enc_param_vals  = nn.Parameter(torch.tensor([np.pi/2+0.1*np.random.rand(), -np.pi/2+0.1*np.random.rand()]))
        
        # Parameter for circuit output
#         self.w = nn.Parameter(nn.Parameter(torch.rand(self.output_dim)))
#         self.w = nn.Parameter(torch.tensor([-1,1], dtype=torch.float32))
        
    def forward(self, inputs):
        input_tiled = self.get_input_tiled(inputs)
        input_scaled = self.enc_param_vals * input_tiled
        input_params = input_scaled
    
        expectation = self.qnn.forward(input_params.detach(), self.rot_param_vals.detach())
        
#         action_exp = torch.tensor(expectation) * self.w
#         action_prob = F.softmax(action_exp, dim=1)
        
#         return action_prob
        return expectation

    def backward(self, inputs):
        input_tiled = self.get_input_tiled(inputs)
        input_scaled = self.enc_param_vals * input_tiled
        input_params = input_scaled
        expectation = self.qnn.forward(input_params.detach(), self.rot_param_vals.detach())
        enc_grad, rot_grad = self.qnn.backward(input_params.detach(), self.rot_param_vals.detach())
#         w_grad = torch.tensor(expectation).tile(self.output_dim)
#         return torch.tensor(rot_grad.squeeze()), torch.tensor(enc_grad.squeeze()), w_grad
        return torch.tensor(rot_grad.squeeze()), torch.tensor(enc_grad.squeeze())
    
    def get_input_tiled(self, inputs):
        # Input: State values -> Need to insert into Encoding gates with scaling parameters(encoding params)
        if self.ansatz == 'universal_encoding' or self.ansatz == 'hw_eff':
            input_tiled = inputs.tile(2)
            input_tiled = input_tiled.tile(self.n_layers)
        elif self.ansatz == 'universal':
            input_tiled = torch.zeros((inputs.shape[0], inputs.shape[1]+1))
            input_tiled[:,:2] = inputs
            input_tiled[:,-1] = inputs[:,-1]
        else:
            input_tiled = inputs.tile(self.n_layers)
        return input_tiled

# %%
policy = PQC_with_DataReuploading(n_qubits=2, n_layers=1, output_dim=2, ansatz='omega')

# %%
policy.observables
# Out:
# PauliOp(Pauli('ZZ'), coeff=1.0)

# %%
policy.circuit.draw('mpl')

# %%
inputs = torch.rand((10,2))

# %%
policy.rot_param_vals
# Out:
# Parameter containing:
# tensor([5.9909, 3.7066, 1.7165, 5.7095], requires_grad=True)

# %%
policy.enc_param_vals
# Out:
# Parameter containing:
# tensor([0.4441, 0.1791], requires_grad=True)

# %%
policy.forward(inputs)
# Out:
# array([[-0.6304066 ],
#        [-0.60927435],
#        [-0.69351903],
#        [-0.67762765],
#        [-0.67836866],
#        [-0.60735658],
#        [-0.71059858],
#        [-0.75020827],
#        [-0.614361  ],
#        [-0.79731211]])

# %%
policy.forward(inputs)
# Out:
# array([[-0.6304066 ],
#        [-0.60927435],
#        [-0.69351903],
#        [-0.67762765],
#        [-0.67836866],
#        [-0.60735658],
#        [-0.71059858],
#        [-0.75020827],
#        [-0.614361  ],
#        [-0.79731211]])

# %%
policy.forward(inputs)
# Out:
# array([[-0.6304066 ],
#        [-0.60927435],
#        [-0.69351903],
#        [-0.67762765],
#        [-0.67836866],
#        [-0.60735658],
#        [-0.71059858],
#        [-0.75020827],
#        [-0.614361  ],
#        [-0.79731211]])

# %%
s = time.time()
a,b = policy.backward(inputs)
print(time.time()-s)
# Out:
# 0.21504735946655273

# %% [markdown]
# # Make Quantum Agent

# %%
class QuantumAgent():
    def __init__(self, input_state_dim, n_actions, n_layers=1, ansatz='base'):
        self.policy = PQC_with_DataReuploading(n_qubits=input_state_dim, n_layers=n_layers, 
                                               output_dim=n_actions, observables=None, ansatz=ansatz,
                                               activation='linear')
        self.n_layers = n_layers
        self.variational_optim = torch.optim.Adam([self.policy.rot_param_vals], lr=0.1)
        self.encoding_optim = torch.optim.Adam([self.policy.enc_param_vals], lr=0.1)
#         self.weight_optim = torch.optim.Adam([self.policy.w], lr=0.01)
        
        self.lr = 1
        
        self.optims = [self.variational_optim, self.encoding_optim]
        
    def get_actions(self, input_state):
        return self.policy.forward(input_state)
    
    def update_policy(self, states, returns, batch_size):
        r_grad, e_grad = self.policy.backward(states)
        
#         p_actions = torch.tensor([action_probs[id_action_pairs[i][0], id_action_pairs[i][1]] for i in range(action_probs.shape[0])])
#         p_actions = p_actions.reshape(p_actions.shape[0], -1)
#         action_idxs = id_action_pairs[:,1]
        
        returns = returns.reshape(returns.shape[0], -1)

#         action_weights = agent.policy.w.detach().numpy()[id_action_pairs[:,1]]
#         action_weights = action_weights[:,np.newaxis]        
#         w = agent.policy.w.tile(len(states)).reshape(len(states),-1)
        
#         rot_grad = returns * ( r_grad * torch.tensor(action_weights) - torch.sum(p_actions * w) * r_grad)
#         input_scaled = self.policy.enc_param_vals * self.policy.get_input_tiled(states)        
#         enc_grad = returns * ( e_grad * torch.tensor(action_weights) - input_scaled * torch.sum(p_actions * w) * e_grad)
        
        rot_grad = returns * r_grad
        enc_grad = returns * e_grad

#         weight_grad = returns * ( w_grad * torch.tensor(action_weights) - torch.sum(p_actions * w) * w_grad)
        
        prev = self.policy.rot_param_vals.detach().numpy().copy()
        prev1 = self.policy.enc_param_vals.detach().numpy().copy()
#         prev2 = self.policy.w.detach().numpy().copy()
        
#         rot_update = (torch.mean(rot_grad.detach(), dim=0) / batch_size).type(torch.float32)
#         enc_update = (torch.mean(enc_grad, dim=0).detach() / batch_size).type(torch.float32)
#         w_update = (torch.mean(weight_grad, dim=0).detach() / batch_size).type(torch.float32)
        
        rot_update = torch.mean(rot_grad, dim=0) / batch_size
        enc_update = torch.mean(enc_grad, dim=0) / batch_size
#         w_update = torch.mean(weight_grad, dim=0) / batch_size
        
        
        with torch.no_grad():            
            self.policy.rot_param_vals += self.lr * rot_update
            self.policy.enc_param_vals += self.lr * enc_update
#             self.policy.w += 0.1 * w_update
    
#         self.policy.rot_param_vals.grad = -1*rot_update
#         self.policy.enc_param_vals.grad = -1*enc_update
#         self.policy.w.grad = -1*w_update
                
#         print(rot_update)
#         print(enc_update)
        
#         self.variational_optim.step()
#         self.encoding_optim.step()
#         self.weight_optim.step()

        print(self.policy.rot_param_vals.detach() - prev)
        print(rot_update)
        print(self.policy.enc_param_vals.detach() - prev1)
        print(enc_update)
#         print(self.policy.w.detach() - prev2)
#         print(w_update)
        
#         print('w', self.policy.w)
        
#         with torch.no_grad():
#             self.policy.rot_param_vals[self.policy.rot_param_vals > 2*np.pi] = 2*np.pi
#             self.policy.enc_param_vals[self.policy.enc_param_vals > 2*np.pi] = 2*np.pi
#             self.policy.rot_param_vals[self.policy.rot_param_vals < 0] = 0
#             self.policy.enc_param_vals[self.policy.enc_param_vals < 0] = 0
        
#         print(self.policy.rot_param_vals)

# %%
n_qubits = 2 # Dimension of the state vectors in CartPole
n_layers = 1
n_actions = 2 # Number of actions in CartPole
agent = QuantumAgent(input_state_dim = n_qubits, n_actions=n_actions, n_layers=n_layers, ansatz='omega')

# %%
agent.policy.circuit.draw('mpl')

# %% [markdown]
# # Run Episodes and Update Policy

# %%
def gather_episodes(state_bounds, n_actions, agent, n_episodes, env_name):
    """Interact with environment in batched fashion."""

    trajectories = [defaultdict(list) for _ in range(n_episodes)]
    if env_name == 'Curling':
        envs = [Curling(reward_type='each_end_counts') for _ in range(n_episodes)]
    else:
        envs = [gym.make(env_name) for _ in range(n_episodes)]

    done = [False for _ in range(n_episodes)]
    states = [e.reset() for e in envs]
    

    while not all(done):
        unfinished_ids = [i for i in range(n_episodes) if not done[i]]
        normalized_states = [s for i, s in enumerate(states) if not done[i]]

        for i, state in zip(unfinished_ids, normalized_states):
            trajectories[i]['states'].append(state)

        states = torch.from_numpy(np.array(normalized_states))
        action_probs = agent.get_actions(states)

        # Store action and transition all environments to the next state
        states = [None for i in range(n_episodes)]
        
        for i, action_prob in zip(unfinished_ids, action_probs):
            if action_prob < 0.5:
                action = 1
            else:
                action = 0
            states[i], reward, done[i], _ = envs[i].step(action)
            trajectories[i]['actions'].append(action)
            trajectories[i]['rewards'].append(reward)  
        
    return trajectories

def compute_returns(rewards_history, gamma):
    """Compute discounted returns with discount factor `gamma`."""
    returns = []
    discounted_sum = 0
    for r in rewards_history[::-1]:
        discounted_sum = r + gamma * discounted_sum
        returns.insert(0, discounted_sum)

    # Normalize them for faster and more stable learning
    returns = np.array(returns)
    returns = (returns - np.mean(returns)) / (np.std(returns) + 1e-8)
    returns = returns.tolist()

    return returns

# %%
env_name = "Curling"
# env_name = "Curling"
if env_name == "CartPole-v1":
    state_bounds = np.array([2.4, 2.5, 0.21, 2.5])
elif env_name == 'Curling':
    state_bounds = np.array([0, 1])
gamma = 1
batch_size = 10
n_episodes = 1000

# %%
# Start training the agent
episode_reward_history = []
# Monitoring reward
monitor_reward_history = []
for batch in tqdm(range(n_episodes // batch_size)):
    # Gather episodes
    episodes = gather_episodes(state_bounds, n_actions, agent, batch_size, env_name)

    # Group states, actions and returns in numpy arrays
    states = torch.from_numpy(np.concatenate([ep['states'] for ep in episodes]))
    actions = torch.from_numpy(np.concatenate([ep['actions'] for ep in episodes]))
#     action_probs = torch.from_numpy(np.concatenate([ep['action probs'] for ep in episodes]))
    rewards = [ep['rewards'] for ep in episodes]
    returns = np.concatenate([compute_returns(ep_rwds, gamma) for ep_rwds in rewards])
    returns = torch.from_numpy(np.array(returns))

#     id_action_pairs = torch.from_numpy(np.array([[i, a] for i, a in enumerate(actions)]))

    # Update model parameters.
    agent.update_policy(states, returns, batch_size)
#     print(action_probs)

    if batch % 5 == 1:
        agent.lr *= 0.5
        # Gather episodes
        episodes = gather_episodes(state_bounds, n_actions, agent, 50, env_name)

        # Group states, actions and returns in numpy arrays
        states = torch.from_numpy(np.concatenate([ep['states'] for ep in episodes]))
        actions = torch.from_numpy(np.concatenate([ep['actions'] for ep in episodes]))
        rewards = [ep['rewards'] for ep in episodes]
        # Store collected rewards
        temp_hist = []
        for ep_rwds in rewards:
            temp_hist.append(np.sum(ep_rwds))
        avg_rewards = np.mean(temp_hist)
        monitor_reward_history.append(avg_rewards)
        
        print('Monitored episode', 50,
              'Average Monitored rewards: ', avg_rewards)

    # Store collected rewards
    for ep_rwds in rewards:
        episode_reward_history.append(np.sum(ep_rwds))

    avg_rewards = np.mean(episode_reward_history[-batch_size:])

    print('Finished episode', (batch + 1) * batch_size,
          'Average rewards: ', avg_rewards)

    if avg_rewards >= 500.0:
        break
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# tensor([-3.3367e-02, -7.8440e-05,  0.0000e+00,  0.0000e+00])
# tensor([-3.3367e-02, -7.8519e-05, -1.1035e-19, -1.8296e-18],
#        dtype=torch.float64)
# tensor([0.0333, 0.0000])
# tensor([3.3342e-02, 5.7033e-20], dtype=torch.float64)
# Finished episode 10 Average rewards:  94.6
# tensor([-0.0353, -0.0002,  0.0000,  0.0000])
# tensor([-3.5254e-02, -1.7872e-04,  7.4035e-19, -1.2417e-18],
#        dtype=torch.float64)
# tensor([0.0352, 0.0000])
# tensor([ 3.5226e-02, -2.9913e-18], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  92.28
# Finished episode 20 Average rewards:  97.4
# tensor([-1.9692e-02, -8.1062e-05,  0.0000e+00,  0.0000e+00])
# tensor([-3.9384e-02, -1.6228e-04,  2.1166e-18, -7.8961e-19],
#        dtype=torch.float64)
# tensor([0.0197, 0.0000])
# tensor([ 3.9353e-02, -1.1218e-19], dtype=torch.float64)
# Finished episode 30 Average rewards:  93.4
# tensor([-0.0178, -0.0001,  0.0000,  0.0000])
# tensor([-3.5541e-02, -2.1054e-04, -4.7012e-18, -1.0482e-19],
#        dtype=torch.float64)
# tensor([0.0178, 0.0000])
# tensor([3.5513e-02, 1.0266e-18], dtype=torch.float64)
# Finished episode 40 Average rewards:  84.4
# tensor([-2.2999e-02, -7.4148e-05,  0.0000e+00,  0.0000e+00])
# tensor([-4.5998e-02, -1.4822e-04, -1.8330e-18, -3.4716e-19],
#        dtype=torch.float64)
# tensor([0.0230, 0.0000])
# tensor([ 4.5962e-02, -3.4704e-19], dtype=torch.float64)
# Finished episode 50 Average rewards:  104.2
# tensor([-0.0199, -0.0001,  0.0000,  0.0000])
# tensor([-3.9857e-02, -2.0763e-04,  6.1705e-19, -1.0123e-18],
#        dtype=torch.float64)
# tensor([0.0199, 0.0000])
# tensor([ 3.9826e-02, -1.0402e-18], dtype=torch.float64)
# Finished episode 60 Average rewards:  93.7
# tensor([-0.0191, -0.0001,  0.0000,  0.0000])
# tensor([-3.8280e-02, -2.0737e-04,  2.3890e-18,  1.1447e-18],
#        dtype=torch.float64)
# tensor([0.0191, 0.0000])
# tensor([ 3.8250e-02, -2.3050e-18], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  93.56
# Finished episode 70 Average rewards:  52.0
# tensor([-8.6715e-03, -6.3896e-05,  0.0000e+00,  0.0000e+00])
# tensor([-3.4687e-02, -2.5565e-04,  2.4430e-18, -4.9890e-20],
#        dtype=torch.float64)
# tensor([0.0087, 0.0000])
# tensor([ 3.4658e-02, -7.3749e-19], dtype=torch.float64)
# Finished episode 80 Average rewards:  94.0
# tensor([-7.8106e-03, -5.4836e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.1242e-02, -2.2055e-05,  2.4595e-18, -4.7545e-18],
#        dtype=torch.float64)
# tensor([0.0078, 0.0000])
# tensor([ 3.1219e-02, -2.7420e-19], dtype=torch.float64)
# Finished episode 90 Average rewards:  82.4
# tensor([-9.9940e-03, -4.1008e-05,  0.0000e+00,  0.0000e+00])
# tensor([-3.9976e-02, -1.6400e-04, -3.3554e-18, -2.1840e-18],
#        dtype=torch.float64)
# tensor([0.0100, 0.0000])
# tensor([ 3.9945e-02, -1.3396e-19], dtype=torch.float64)
# Finished episode 100 Average rewards:  103.3
# tensor([-8.0576e-03, -7.0333e-05,  0.0000e+00,  0.0000e+00])
# tensor([-3.2230e-02, -2.8086e-04,  4.5912e-19, -3.1946e-18],
#        dtype=torch.float64)
# tensor([0.0081, 0.0000])
# tensor([3.2203e-02, 1.0179e-18], dtype=torch.float64)
# Finished episode 110 Average rewards:  104.9
# tensor([-1.0049e-02, -1.5020e-05,  0.0000e+00,  0.0000e+00])
# tensor([-4.0197e-02, -6.0069e-05, -2.8930e-19, -4.5394e-19],
#        dtype=torch.float64)
# tensor([0.0100, 0.0000])
# tensor([ 4.0168e-02, -8.6228e-19], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  104.92
# Finished episode 120 Average rewards:  104.3
# tensor([-3.7796e-03, -2.4796e-05,  0.0000e+00,  0.0000e+00])
# tensor([-3.0237e-02, -1.9898e-04,  1.3267e-18, -3.0946e-18],
#        dtype=torch.float64)
# tensor([0.0038, 0.0000])
# tensor([3.0213e-02, 8.5537e-19], dtype=torch.float64)
# Finished episode 130 Average rewards:  92.7
# tensor([-4.7030e-03, -3.0994e-05,  0.0000e+00,  0.0000e+00])
# tensor([-3.7625e-02, -2.4702e-04,  5.5425e-18, -1.2492e-18],
#        dtype=torch.float64)
# tensor([0.0047, 0.0000])
# tensor([ 3.7594e-02, -8.7993e-19], dtype=torch.float64)
# Finished episode 140 Average rewards:  92.6
# tensor([-5.1892e-03, -2.8133e-05,  0.0000e+00,  0.0000e+00])
# tensor([-4.1513e-02, -2.2426e-04, -4.1594e-18, -7.9860e-18],
#        dtype=torch.float64)
# tensor([0.0052, 0.0000])
# tensor([ 4.1480e-02, -1.5807e-18], dtype=torch.float64)
# Finished episode 150 Average rewards:  91.8
# tensor([-5.0054e-03, -4.3154e-05,  0.0000e+00,  0.0000e+00])
# tensor([-4.0043e-02, -3.4469e-04,  4.7193e-19, -3.2654e-19],
#        dtype=torch.float64)
# tensor([0.0050, 0.0000])
# tensor([4.0009e-02, 1.1743e-18], dtype=torch.float64)
# Finished episode 160 Average rewards:  93.3
# tensor([-4.2009e-03, -2.5272e-05,  0.0000e+00,  0.0000e+00])
# tensor([-3.3607e-02, -2.0200e-04, -2.4296e-18, -7.9865e-18],
#        dtype=torch.float64)
# tensor([0.0042, 0.0000])
# tensor([3.3580e-02, 1.7162e-19], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  96.44
# Finished episode 170 Average rewards:  105.6
# tensor([-2.0154e-03, -1.2398e-05,  0.0000e+00,  0.0000e+00])
# tensor([-3.2246e-02, -1.9970e-04,  6.0253e-18, -2.9501e-18],
#        dtype=torch.float64)
# tensor([0.0020, 0.0000])
# tensor([3.2220e-02, 1.7758e-19], dtype=torch.float64)
# Finished episode 180 Average rewards:  85.0
# tensor([-2.0978e-03, -1.3590e-05,  0.0000e+00,  0.0000e+00])
# tensor([-3.3566e-02, -2.1854e-04,  8.9632e-19, -8.2942e-19],
#        dtype=torch.float64)
# tensor([0.0021, 0.0000])
# tensor([ 3.3539e-02, -1.1682e-18], dtype=torch.float64)
# Finished episode 190 Average rewards:  85.3
# tensor([-2.2523e-03, -3.8147e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.6037e-02, -6.2295e-05, -6.8668e-19, -3.7766e-18],
#        dtype=torch.float64)
# tensor([0.0023, 0.0000])
# tensor([ 3.6010e-02, -2.2865e-19], dtype=torch.float64)
# Finished episode 200 Average rewards:  91.8
# tensor([-1.8253e-03, -1.2159e-05,  0.0000e+00,  0.0000e+00])
# tensor([-2.9205e-02, -1.9469e-04,  2.5683e-18, -2.1978e-18],
#        dtype=torch.float64)
# tensor([0.0018, 0.0000])
# tensor([2.9181e-02, 6.0075e-19], dtype=torch.float64)
# Finished episode 210 Average rewards:  104.2
# tensor([-2.0294e-03, -2.2888e-05,  0.0000e+00,  0.0000e+00])
# tensor([-3.2471e-02, -3.6498e-04,  1.2687e-19,  8.2030e-19],
#        dtype=torch.float64)
# tensor([0.0020, 0.0000])
# tensor([3.2442e-02, 8.3596e-19], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  100.58
# Finished episode 220 Average rewards:  105.4
# tensor([-1.1675e-03, -8.1062e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.7360e-02, -2.5646e-04,  1.2052e-18,  2.2375e-18],
#        dtype=torch.float64)
# tensor([0.0012, 0.0000])
# tensor([ 3.7330e-02, -1.3848e-18], dtype=torch.float64)
# Finished episode 230 Average rewards:  95.3
# tensor([-8.2827e-04, -1.0490e-05,  0.0000e+00,  0.0000e+00])
# tensor([-2.6508e-02, -3.3396e-04, -5.7730e-19,  9.0488e-19],
#        dtype=torch.float64)
# tensor([0.0008, 0.0000])
# tensor([ 2.6484e-02, -8.4162e-19], dtype=torch.float64)
# Finished episode 240 Average rewards:  106.1
# tensor([-1.2636e-03, -1.0490e-05,  0.0000e+00,  0.0000e+00])
# tensor([-4.0435e-02, -3.3250e-04, -1.3305e-19, -3.2373e-18],
#        dtype=torch.float64)
# tensor([0.0013, 0.0000])
# tensor([4.0401e-02, 9.8633e-19], dtype=torch.float64)
# Finished episode 250 Average rewards:  93.6
# tensor([-1.1306e-03, -6.6757e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.6177e-02, -2.1004e-04, -4.2040e-18, -5.8213e-18],
#        dtype=torch.float64)
# tensor([0.0011, 0.0000])
# tensor([ 3.6148e-02, -7.5256e-20], dtype=torch.float64)
# Finished episode 260 Average rewards:  95.2
# tensor([-1.1172e-03, -6.9141e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.5750e-02, -2.2323e-04, -2.1872e-18, -5.1274e-18],
#        dtype=torch.float64)
# tensor([0.0011, 0.0000])
# tensor([3.5721e-02, 2.8067e-19], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  92.84
# Finished episode 270 Average rewards:  93.7
# tensor([-5.8603e-04, -2.8610e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.7499e-02, -1.7674e-04,  1.0293e-18, -4.1954e-18],
#        dtype=torch.float64)
# tensor([0.0006, 0.0000])
# tensor([3.7470e-02, 5.6474e-19], dtype=torch.float64)
# Finished episode 280 Average rewards:  105.0
# tensor([-6.5279e-04, -2.3842e-06,  0.0000e+00,  0.0000e+00])
# tensor([-4.1773e-02, -1.5909e-04,  1.4219e-18, -1.1240e-18],
#        dtype=torch.float64)
# tensor([0.0007, 0.0000])
# tensor([ 4.1741e-02, -2.0303e-19], dtype=torch.float64)
# Finished episode 290 Average rewards:  92.7
# tensor([-4.8780e-04, -2.8610e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.1227e-02, -1.7800e-04,  4.6426e-18, -2.1053e-18],
#        dtype=torch.float64)
# tensor([0.0005, 0.0000])
# tensor([3.1202e-02, 2.0933e-18], dtype=torch.float64)
# Finished episode 300 Average rewards:  93.9
# tensor([-4.4417e-04, -4.7684e-06,  0.0000e+00,  0.0000e+00])
# tensor([-2.8426e-02, -3.0772e-04, -2.2698e-18, -2.7025e-19],
#        dtype=torch.float64)
# tensor([0.0004, 0.0000])
# tensor([ 2.8401e-02, -1.8448e-19], dtype=torch.float64)
# Finished episode 310 Average rewards:  105.4
# tensor([-4.3321e-04, -5.0068e-06,  0.0000e+00,  0.0000e+00])
# tensor([-2.7731e-02, -3.1421e-04,  1.8990e-18,  1.8169e-18],
#        dtype=torch.float64)
# tensor([0.0004, 0.0000])
# tensor([2.7706e-02, 7.1736e-19], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  92.68
# Finished episode 320 Average rewards:  103.9
# tensor([-2.6321e-04, -2.1458e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.3677e-02, -2.8558e-04,  2.2749e-18, -3.5243e-18],
#        dtype=torch.float64)
# tensor([0.0003, 0.0000])
# tensor([3.3649e-02, 1.5642e-18], dtype=torch.float64)
# Finished episode 330 Average rewards:  103.6
# tensor([-3.0947e-04, -1.1921e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.9611e-02, -1.6586e-04, -5.5908e-18, -3.7380e-18],
#        dtype=torch.float64)
# tensor([0.0003, 0.0000])
# tensor([3.9581e-02, 7.7057e-19], dtype=torch.float64)
# Finished episode 340 Average rewards:  82.5
# tensor([-2.5105e-04, -1.6689e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.2142e-02, -2.1809e-04,  4.8395e-18, -9.1217e-19],
#        dtype=torch.float64)
# tensor([0.0003, 0.0000])
# tensor([3.2116e-02, 6.2903e-19], dtype=torch.float64)
# Finished episode 350 Average rewards:  105.6
# tensor([-3.6120e-04, -1.1921e-06,  0.0000e+00,  0.0000e+00])
# tensor([-4.6242e-02, -1.6590e-04, -1.5505e-18, -5.6666e-18],
#        dtype=torch.float64)
# tensor([0.0004, 0.0000])
# tensor([ 4.6207e-02, -9.1782e-19], dtype=torch.float64)
# Finished episode 360 Average rewards:  91.8
# tensor([-2.4819e-04, -1.9073e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.1768e-02, -2.3049e-04,  5.2019e-20, -4.2544e-18],
#        dtype=torch.float64)
# tensor([0.0002, 0.0000])
# tensor([3.1742e-02, 1.2915e-18], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  91.92
# Finished episode 370 Average rewards:  93.4
# tensor([-1.5879e-04, -4.7684e-07,  0.0000e+00,  0.0000e+00])
# tensor([-4.0641e-02, -1.2545e-04, -8.9996e-19, -3.6308e-18],
#        dtype=torch.float64)
# tensor([0.0002, 0.0000])
# tensor([ 4.0611e-02, -9.7685e-19], dtype=torch.float64)
# Finished episode 380 Average rewards:  92.1
# tensor([-1.6141e-04, -9.5367e-07,  0.0000e+00,  0.0000e+00])
# tensor([-4.1313e-02, -2.6804e-04,  5.8439e-18, -4.9714e-18],
#        dtype=torch.float64)
# tensor([0.0002, 0.0000])
# tensor([4.1279e-02, 1.0738e-18], dtype=torch.float64)
# Finished episode 390 Average rewards:  73.2
# tensor([-1.2517e-04, -1.1921e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.2039e-02, -3.3300e-04, -1.2999e-18, -2.9170e-19],
#        dtype=torch.float64)
# tensor([0.0001, 0.0000])
# tensor([ 3.2011e-02, -6.4700e-19], dtype=torch.float64)
# Finished episode 400 Average rewards:  103.7
# tensor([-1.2469e-04, -9.5367e-07,  0.0000e+00,  0.0000e+00])
# tensor([-3.1945e-02, -2.1975e-04, -2.5943e-18, -4.7551e-18],
#        dtype=torch.float64)
# tensor([0.0001, 0.0000])
# tensor([ 3.1919e-02, -2.1093e-18], dtype=torch.float64)
# Finished episode 410 Average rewards:  95.7
# tensor([-1.2136e-04, -1.1921e-06,  0.0000e+00,  0.0000e+00])
# tensor([-3.1069e-02, -2.9683e-04, -2.4395e-18,  2.7302e-19],
#        dtype=torch.float64)
# tensor([0.0001, 0.0000])
# tensor([ 3.1042e-02, -1.6585e-18], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  96.12
# Finished episode 420 Average rewards:  81.8
# tensor([-6.2227e-05, -4.7684e-07,  0.0000e+00,  0.0000e+00])
# tensor([-3.1886e-02, -2.7840e-04,  3.6700e-18, -1.9803e-18],
#        dtype=torch.float64)
# tensor([6.2227e-05, 0.0000e+00])
# tensor([ 3.1859e-02, -4.7509e-19], dtype=torch.float64)
# Finished episode 430 Average rewards:  94.5
# tensor([-7.1764e-05, -7.1526e-07,  0.0000e+00,  0.0000e+00])
# tensor([-3.6752e-02, -3.2205e-04, -1.8997e-19, -5.2473e-18],
#        dtype=torch.float64)
# tensor([7.1764e-05, 0.0000e+00])
# tensor([3.6721e-02, 5.9482e-19], dtype=torch.float64)
# Finished episode 440 Average rewards:  102.9
# tensor([-4.8399e-05, -7.1526e-07,  0.0000e+00,  0.0000e+00])
# tensor([-2.4809e-02, -3.4121e-04, -3.1371e-18, -1.7783e-18],
#        dtype=torch.float64)
# tensor([4.8399e-05, 0.0000e+00])
# tensor([ 2.4786e-02, -6.6512e-19], dtype=torch.float64)
# Finished episode 450 Average rewards:  107.5
# tensor([-5.9843e-05, -7.1526e-07,  0.0000e+00,  0.0000e+00])
# tensor([-3.0602e-02, -4.0670e-04, -5.0347e-20, -5.5398e-18],
#        dtype=torch.float64)
# tensor([5.9724e-05, 0.0000e+00])
# tensor([3.0574e-02, 4.4917e-19], dtype=torch.float64)
# Finished episode 460 Average rewards:  94.5
# tensor([-8.5831e-05, -4.7684e-07,  0.0000e+00,  0.0000e+00])
# tensor([-4.3932e-02, -1.9266e-04, -2.6250e-18, -4.0745e-18],
#        dtype=torch.float64)
# tensor([8.5711e-05, 0.0000e+00])
# tensor([ 4.3898e-02, -1.2233e-18], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  98.5
# Finished episode 470 Average rewards:  104.4
# tensor([-3.3140e-05, -4.7684e-07,  0.0000e+00,  0.0000e+00])
# tensor([-3.4000e-02, -4.2754e-04,  1.0403e-18,  6.1844e-19],
#        dtype=torch.float64)
# tensor([3.3140e-05, 0.0000e+00])
# tensor([3.3969e-02, 2.6918e-18], dtype=torch.float64)
# Finished episode 480 Average rewards:  92.5
# tensor([-3.0756e-05, -2.3842e-07,  0.0000e+00,  0.0000e+00])
# tensor([-3.1603e-02, -2.7711e-04, -6.5202e-19, -4.1495e-18],
#        dtype=torch.float64)
# tensor([3.0875e-05, 0.0000e+00])
# tensor([3.1576e-02, 3.3328e-19], dtype=torch.float64)
# Finished episode 490 Average rewards:  94.5
# tensor([-4.0293e-05, -2.3842e-07,  0.0000e+00,  0.0000e+00])
# tensor([-4.1351e-02, -2.8381e-04, -2.3877e-19, -1.8662e-18],
#        dtype=torch.float64)
# tensor([4.0293e-05, 0.0000e+00])
# tensor([ 4.1318e-02, -1.8571e-18], dtype=torch.float64)
# Finished episode 500 Average rewards:  83.6
# tensor([-4.3392e-05, -2.3842e-07,  0.0000e+00,  0.0000e+00])
# tensor([-4.4488e-02, -2.3957e-04, -8.1937e-19, -8.6204e-18],
#        dtype=torch.float64)
# tensor([4.3392e-05, 0.0000e+00])
# tensor([ 4.4453e-02, -2.6827e-19], dtype=torch.float64)
# Finished episode 510 Average rewards:  94.3
# tensor([-4.3631e-05, -2.3842e-07,  0.0000e+00,  0.0000e+00])
# tensor([-4.4651e-02, -2.1308e-04,  1.1044e-18, -2.4342e-19],
#        dtype=torch.float64)
# tensor([4.3511e-05, 0.0000e+00])
# tensor([ 4.4616e-02, -3.1597e-18], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  95.6
# Finished episode 520 Average rewards:  104.6
# tensor([-1.8597e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.8140e-02, -1.7645e-04, -2.1195e-18, -5.3691e-18],
#        dtype=torch.float64)
# tensor([1.8597e-05, 0.0000e+00])
# tensor([3.8110e-02, 4.8313e-19], dtype=torch.float64)
# Finished episode 530 Average rewards:  104.2
# tensor([-2.0266e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-4.1466e-02, -8.2556e-05,  3.3239e-18,  2.8778e-18],
#        dtype=torch.float64)
# tensor([2.0266e-05, 0.0000e+00])
# tensor([4.1436e-02, 1.7851e-18], dtype=torch.float64)
# Finished episode 540 Average rewards:  93.0
# tensor([-1.6689e-05, -2.3842e-07,  0.0000e+00,  0.0000e+00])
# tensor([-3.4167e-02, -2.4664e-04, -4.4488e-18, -4.4723e-18],
#        dtype=torch.float64)
# tensor([1.6689e-05, 0.0000e+00])
# tensor([ 3.4139e-02, -4.8284e-19], dtype=torch.float64)
# Finished episode 550 Average rewards:  95.0
# tensor([-1.6212e-05, -2.3842e-07,  0.0000e+00,  0.0000e+00])
# tensor([-3.3424e-02, -2.4892e-04, -6.3695e-18, -7.1000e-18],
#        dtype=torch.float64)
# tensor([1.6332e-05, 0.0000e+00])
# tensor([ 3.3396e-02, -3.8911e-19], dtype=torch.float64)
# Finished episode 560 Average rewards:  105.5
# tensor([-1.0729e-05, -2.3842e-07,  0.0000e+00,  0.0000e+00])
# tensor([-2.2041e-02, -2.5757e-04,  2.7953e-18, -1.2227e-18],
#        dtype=torch.float64)
# tensor([1.0729e-05, 0.0000e+00])
# tensor([2.2021e-02, 1.7206e-19], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  96.5
# Finished episode 570 Average rewards:  94.2
# tensor([-9.5367e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.9540e-02, -2.8648e-04, -4.7519e-18, -7.4215e-18],
#        dtype=torch.float64)
# tensor([9.6560e-06, 0.0000e+00])
# tensor([3.9508e-02, 2.9391e-18], dtype=torch.float64)
# Finished episode 580 Average rewards:  102.8
# tensor([-9.5367e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.8783e-02, -2.9562e-04, -1.3124e-18, -3.6136e-18],
#        dtype=torch.float64)
# tensor([9.4175e-06, 0.0000e+00])
# tensor([3.8751e-02, 2.4447e-18], dtype=torch.float64)
# Finished episode 590 Average rewards:  93.2
# tensor([-7.1526e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-2.9733e-02, -3.2150e-04, -4.1836e-18, -2.4076e-18],
#        dtype=torch.float64)
# tensor([7.2718e-06, 0.0000e+00])
# tensor([ 2.9707e-02, -1.7682e-19], dtype=torch.float64)
# Finished episode 600 Average rewards:  105.0
# tensor([-8.3447e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.3981e-02, -1.8614e-04,  9.6410e-19, -3.8047e-18],
#        dtype=torch.float64)
# tensor([8.3447e-06, 0.0000e+00])
# tensor([3.3954e-02, 4.3786e-19], dtype=torch.float64)
# Finished episode 610 Average rewards:  82.1
# tensor([-8.1062e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.3291e-02, -1.9772e-04, -4.7509e-18,  2.6276e-18],
#        dtype=torch.float64)
# tensor([8.1062e-06, 0.0000e+00])
# tensor([ 3.3264e-02, -3.6231e-19], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  95.74
# Finished episode 620 Average rewards:  95.0
# tensor([-4.0531e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.2251e-02, -2.7838e-04, -2.3587e-18, -4.6996e-18],
#        dtype=torch.float64)
# tensor([3.9339e-06, 0.0000e+00])
# tensor([3.2223e-02, 6.6917e-19], dtype=torch.float64)
# Finished episode 630 Average rewards:  106.1
# tensor([-5.2452e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-4.2084e-02, -1.0013e-04, -2.5367e-18, -9.1402e-18],
#        dtype=torch.float64)
# tensor([5.1260e-06, 0.0000e+00])
# tensor([4.2053e-02, 8.0683e-19], dtype=torch.float64)
# Finished episode 640 Average rewards:  83.2
# tensor([-4.2915e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.5661e-02, -2.7161e-04, -6.4444e-18,  1.1412e-18],
#        dtype=torch.float64)
# tensor([4.2915e-06, 0.0000e+00])
# tensor([ 3.5631e-02, -9.0454e-19], dtype=torch.float64)
# Finished episode 650 Average rewards:  103.3
# tensor([-4.0531e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.3055e-02, -2.5323e-04,  2.3322e-18, -1.1462e-18],
#        dtype=torch.float64)
# tensor([4.0531e-06, 0.0000e+00])
# tensor([ 3.3027e-02, -3.8109e-19], dtype=torch.float64)
# Finished episode 660 Average rewards:  93.3
# tensor([-4.2915e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.4683e-02, -3.4238e-04,  4.4814e-18, -3.4160e-18],
#        dtype=torch.float64)
# tensor([4.1723e-06, 0.0000e+00])
# tensor([3.4653e-02, 1.1638e-18], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  100.42
# Finished episode 670 Average rewards:  94.2
# tensor([-1.9073e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.0479e-02, -3.2018e-04,  5.8255e-18, -4.7428e-18],
#        dtype=torch.float64)
# tensor([1.9073e-06, 0.0000e+00])
# tensor([3.0453e-02, 1.2602e-18], dtype=torch.float64)
# Finished episode 680 Average rewards:  104.6
# tensor([-2.6226e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-4.2712e-02, -1.2480e-04,  2.7090e-18,  1.4233e-18],
#        dtype=torch.float64)
# tensor([2.6226e-06, 0.0000e+00])
# tensor([ 4.2680e-02, -1.5219e-19], dtype=torch.float64)
# Finished episode 690 Average rewards:  92.9
# tensor([-2.8610e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-4.5390e-02, -1.0307e-04,  4.7051e-18, -3.5116e-19],
#        dtype=torch.float64)
# tensor([2.7418e-06, 0.0000e+00])
# tensor([ 4.5356e-02, -9.9399e-19], dtype=torch.float64)
# Finished episode 700 Average rewards:  92.2
# tensor([-2.3842e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.9748e-02, -3.0284e-04, -6.8102e-19, -1.2872e-18],
#        dtype=torch.float64)
# tensor([2.3842e-06, 0.0000e+00])
# tensor([3.9715e-02, 4.1693e-19], dtype=torch.float64)
# Finished episode 710 Average rewards:  83.4
# tensor([-2.1458e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.3620e-02, -1.9352e-04,  2.2822e-18, -1.2145e-18],
#        dtype=torch.float64)
# tensor([2.0266e-06, 0.0000e+00])
# tensor([ 3.3593e-02, -1.3283e-18], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  90.24
# Finished episode 720 Average rewards:  94.6
# tensor([-9.5367e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.0827e-02, -3.2099e-04, -2.0899e-19,  1.9221e-18],
#        dtype=torch.float64)
# tensor([9.5367e-07, 0.0000e+00])
# tensor([ 3.0800e-02, -8.4771e-19], dtype=torch.float64)
# Finished episode 730 Average rewards:  104.1
# tensor([-1.1921e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.8802e-02, -1.8092e-04,  3.2844e-18,  1.1128e-18],
#        dtype=torch.float64)
# tensor([1.1921e-06, 0.0000e+00])
# tensor([3.8772e-02, 1.0305e-18], dtype=torch.float64)
# Finished episode 740 Average rewards:  103.9
# tensor([-7.1526e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-2.6208e-02, -3.0829e-04, -1.4915e-18, -7.3956e-19],
#        dtype=torch.float64)
# tensor([8.3447e-07, 0.0000e+00])
# tensor([2.6185e-02, 3.0377e-19], dtype=torch.float64)
# Finished episode 750 Average rewards:  106.7
# tensor([-1.1921e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.8199e-02, -1.6571e-04, -6.6186e-18,  2.1056e-18],
#        dtype=torch.float64)
# tensor([1.1921e-06, 0.0000e+00])
# tensor([3.8170e-02, 4.2203e-19], dtype=torch.float64)
# Finished episode 760 Average rewards:  102.4
# tensor([-1.1921e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-4.0866e-02, -1.0616e-04,  3.8645e-18, -3.5021e-18],
#        dtype=torch.float64)
# tensor([1.1921e-06, 0.0000e+00])
# tensor([4.0835e-02, 4.3398e-19], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  103.56
# Finished episode 770 Average rewards:  105.4
# tensor([-4.7684e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-2.9784e-02, -3.0182e-04, -1.7865e-18,  8.6894e-19],
#        dtype=torch.float64)
# tensor([4.7684e-07, 0.0000e+00])
# tensor([ 2.9758e-02, -1.1577e-18], dtype=torch.float64)
# Finished episode 780 Average rewards:  93.4
# tensor([-7.1526e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-4.0171e-02, -2.5942e-04,  3.5528e-18, -8.0586e-18],
#        dtype=torch.float64)
# tensor([5.9605e-07, 0.0000e+00])
# tensor([4.0138e-02, 5.5430e-19], dtype=torch.float64)
# Finished episode 790 Average rewards:  102.9
# tensor([-4.7684e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.6361e-02, -2.9540e-04,  1.9243e-18, -3.1718e-18],
#        dtype=torch.float64)
# tensor([5.9605e-07, 0.0000e+00])
# tensor([3.6331e-02, 2.1568e-19], dtype=torch.float64)
# Finished episode 800 Average rewards:  106.5
# tensor([-7.1526e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.9814e-02, -1.1851e-04, -2.6785e-18,  5.2790e-19],
#        dtype=torch.float64)
# tensor([5.9605e-07, 0.0000e+00])
# tensor([3.9785e-02, 1.1518e-18], dtype=torch.float64)
# Finished episode 810 Average rewards:  93.2
# tensor([-4.7684e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.3557e-02, -2.9361e-04,  5.0126e-18,  8.9718e-19],
#        dtype=torch.float64)
# tensor([4.7684e-07, 0.0000e+00])
# tensor([3.3529e-02, 4.0495e-19], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  91.74
# Finished episode 820 Average rewards:  94.8
# tensor([-2.3842e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.0809e-02, -3.1596e-04, -1.8097e-18,  2.1178e-19],
#        dtype=torch.float64)
# tensor([2.3842e-07, 0.0000e+00])
# tensor([ 3.0782e-02, -8.1381e-19], dtype=torch.float64)
# Finished episode 830 Average rewards:  105.8
# tensor([-2.3842e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-2.2658e-02, -4.1176e-04, -5.2809e-19, -8.7653e-19],
#        dtype=torch.float64)
# tensor([1.1921e-07, 0.0000e+00])
# tensor([2.2635e-02, 1.4701e-18], dtype=torch.float64)
# Finished episode 840 Average rewards:  107.0
# tensor([-2.3842e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.6093e-02, -2.1961e-04, -2.5591e-18, -6.5359e-19],
#        dtype=torch.float64)
# tensor([2.3842e-07, 0.0000e+00])
# tensor([ 3.6064e-02, -1.1521e-18], dtype=torch.float64)
# Finished episode 850 Average rewards:  83.4
# tensor([-2.3842e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-2.5866e-02, -2.7250e-04, -1.4582e-18, -4.0960e-19],
#        dtype=torch.float64)
# tensor([2.3842e-07, 0.0000e+00])
# tensor([2.5843e-02, 1.7599e-18], dtype=torch.float64)
# Finished episode 860 Average rewards:  105.6
# tensor([-2.3842e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.4179e-02, -3.0370e-04,  5.4510e-18, -3.4109e-18],
#        dtype=torch.float64)
# tensor([2.3842e-07, 0.0000e+00])
# tensor([ 3.4150e-02, -7.9915e-19], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  101.72
# Finished episode 870 Average rewards:  107.9
# tensor([-2.3842e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.9337e-02, -1.6590e-04,  2.1497e-18,  2.8672e-18],
#        dtype=torch.float64)
# tensor([1.1921e-07, 0.0000e+00])
# tensor([3.9307e-02, 1.5953e-18], dtype=torch.float64)
# Finished episode 880 Average rewards:  103.0
# tensor([0., 0., 0., 0.])
# tensor([-2.4526e-02, -2.6151e-04, -1.1949e-18, -3.3324e-18],
#        dtype=torch.float64)
# tensor([1.1921e-07, 0.0000e+00])
# tensor([2.4505e-02, 3.3072e-19], dtype=torch.float64)
# Finished episode 890 Average rewards:  106.2
# tensor([-2.3842e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-3.8949e-02, -3.0997e-04, -4.8840e-19, -2.0782e-18],
#        dtype=torch.float64)
# tensor([1.1921e-07, 0.0000e+00])
# tensor([3.8917e-02, 1.2522e-18], dtype=torch.float64)
# Finished episode 900 Average rewards:  104.3
# tensor([-2.3842e-07,  0.0000e+00,  0.0000e+00,  0.0000e+00])
# tensor([-4.4448e-02, -1.5857e-04, -3.0522e-18,  2.3179e-18],
#        dtype=torch.float64)
# tensor([1.1921e-07, 0.0000e+00])
# tensor([4.4414e-02, 2.4405e-18], dtype=torch.float64)
# Finished episode 910 Average rewards:  82.0
# tensor([0., 0., 0., 0.])
# tensor([-3.1182e-02, -2.2200e-04, -3.1546e-18, -5.4274e-18],
#        dtype=torch.float64)
# tensor([1.1921e-07, 0.0000e+00])
# tensor([3.1156e-02, 4.4986e-19], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  92.04
# Finished episode 920 Average rewards:  103.3
# tensor([0., 0., 0., 0.])
# tensor([-3.6228e-02, -3.3726e-04, -1.4415e-18, -4.9528e-18],
#        dtype=torch.float64)
# tensor([1.1921e-07, 0.0000e+00])
# tensor([3.6197e-02, 2.0314e-18], dtype=torch.float64)
# Finished episode 930 Average rewards:  106.5
# tensor([0., 0., 0., 0.])
# tensor([-3.1516e-02, -1.7081e-04, -1.2903e-18, -8.1613e-19],
#        dtype=torch.float64)
# tensor([1.1921e-07, 0.0000e+00])
# tensor([ 3.1491e-02, -1.0514e-19], dtype=torch.float64)
# Finished episode 940 Average rewards:  106.4
# tensor([0., 0., 0., 0.])
# tensor([-4.0681e-02, -2.7272e-04,  5.3375e-18, -2.0116e-18],
#        dtype=torch.float64)
# tensor([1.1921e-07, 0.0000e+00])
# tensor([ 4.0648e-02, -4.1031e-19], dtype=torch.float64)
# Finished episode 950 Average rewards:  104.3
# tensor([0., 0., 0., 0.])
# tensor([-4.3745e-02, -8.0240e-05, -1.0896e-18, -7.0619e-18],
#        dtype=torch.float64)
# tensor([1.1921e-07, 0.0000e+00])
# tensor([ 4.3713e-02, -1.1560e-20], dtype=torch.float64)
# Finished episode 960 Average rewards:  93.9
# tensor([0., 0., 0., 0.])
# tensor([-3.9504e-02, -2.1585e-04, -4.2291e-19,  6.5665e-19],
#        dtype=torch.float64)
# tensor([1.1921e-07, 0.0000e+00])
# tensor([3.9473e-02, 8.5766e-20], dtype=torch.float64)
# Monitored episode 50 Average Monitored rewards:  94.42
# Finished episode 970 Average rewards:  93.0
# tensor([0., 0., 0., 0.])
# tensor([-2.7353e-02, -3.4031e-04,  3.9293e-19, -1.3640e-18],
#        dtype=torch.float64)
# tensor([0., 0.])
# tensor([ 2.7328e-02, -2.0768e-18], dtype=torch.float64)
# Finished episode 980 Average rewards:  104.1
# tensor([0., 0., 0., 0.])
# tensor([-3.4611e-02, -1.3221e-04, -1.5646e-18,  7.2923e-19],
#        dtype=torch.float64)
# tensor([0., 0.])
# tensor([ 3.4584e-02, -1.4946e-18], dtype=torch.float64)
# Finished episode 990 Average rewards:  85.1
# tensor([0., 0., 0., 0.])
# tensor([-3.8155e-02, -1.6060e-04, -1.6496e-18,  1.0374e-18],
#        dtype=torch.float64)
# tensor([0., 0.])
# tensor([ 3.8126e-02, -1.5048e-18], dtype=torch.float64)
# Finished episode 1000 Average rewards:  93.1

# %%
plt.scatter(range(len(episode_reward_history)), episode_reward_history)

# %%
plt.hist(episode_reward_history[:200], bins=30)
plt.hist(episode_reward_history[-200:], bins=30, label='last')
plt.legend()
# plt.savefig('hist.png')

# %%
plt.plot(monitor_reward_history)
# plt.savefig('rewardmonitor.png')
